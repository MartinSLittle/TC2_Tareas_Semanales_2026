# %% [markdown]
# <img src="./Fotos/logo_UTN.svg" align="right" width="150" />
#
# # Tarea Semanal IV
#
# #### Teoría de Circuitos II
# #### Curso R4052
# #### Facultad Regional de Buenos Aires
#
#
#
# Autor: *Martín Sebastián Little*

# %% [markdown]
# ### Introducción
#
# En este trabajo, se realizará el análisis, empezando por su transferencia genérica, diagrama de polos y respuestas de amplitud y de fase. Luego, se analizará la red circuital compuesta por los filtros Sallen-key, filtro Variable de estado y el filtro Multiple Feedback.
